# %% [markdown]
# # Week14 network programming (1)

# %% [markdown]
# # Review
# In the classroom, we learned how to use python to do basic web crawlers and how to use python to send email.
#
# * python crawler
# * send email

# %% [markdown]
# # Tasks
# In this lab, we will practice grabbing the information in the online registration and query system for enrollment of the master’s class(碩士班招生正備取生網路報到查詢系統) and list the number of waiting list of each institute .
# http://gra108.aca.ntu.edu.tw/regbchk/stu_query.asp
#
# <img src=https://i.imgur.com/sJdsCJn.png width=400px>
#
# Please follow the steps below:

# %% [markdown]
# ## Step 1 List all avaliable department
#
# Sample Output:
# <textarea readonly rows="10" cols="80">
# ['1010中國文學系碩士班',
#  '1020外國語文學系碩士班',
#  '1030歷史學系碩士班',
#  '1040哲學系碩士班甲組(主修東方哲學)',
#  '1050哲學系碩士班乙組(主修西方哲學)',
#  '1060人類學系碩士班',
#  '1070圖書資訊學系碩士班甲組',
#  '1080圖書資訊學系碩士班乙組',
#  '1090圖書資訊學系碩士班丙組',
#  '1100日本語文學系碩士班',
#  '1110戲劇學系碩士班',
#  '1120藝術史研究所碩士班',
#  '1130語言學研究所碩士班',
#  '1140音樂學研究所碩士班',
#  '1150臺灣文學研究所碩士班',
#  '2000物理、天文物理、應用物理聯合招生',
#  '2010數學系碩士班',
#  '2020物理學系碩士班',
#  '2030化學系碩士班化學組',
#  '2040化學系碩士班化學生物學組',
#  '2050地質科學系碩士班',
#  '2051地質科學系碩士班地質組',
#  '2052地質科學系碩士班應用地質組',
#  '2060心理學系碩士班一般心理學組',
#  '2070心理學系碩士班臨床心理學組',
#  '2080地理環境資源學系碩士班',
#  '2090大氣科學系碩士班甲組',
#  '2100大氣科學系碩士班乙組',
#  '2110海洋研究所碩士班海洋物理組',
#  '2120海洋研究所碩士班海洋地質及地球物理組',
#  '2130海洋研究所碩士班海洋地質及地球物理組',
#  '2140海洋研究所碩士班海洋化學組',
#  '2150海洋研究所碩士班海洋生物及漁業組',
#  '2160天文物理研究所碩士班',
#  '2170應用物理學研究所碩士班',
#  '2180應用數學科學研究所碩士班應用數學組',
#  '2190應用數學科學研究所碩士班數理統計組',
#  '2200氣候變遷與永續發展國際碩士學位學程',
#  '3010政治學系碩士班甲組(主修政治理論)',
#  '3020政治學系碩士班乙組(主修國際關係)',
#  '3030經濟學系碩士班',
#  '3040社會學系碩士班',
#  '3050社會工作學系碩士班甲組',
#  '3060社會工作學系碩士班乙組',
#  '3070國家發展研究所碩士班甲組(主修全球化與科技治理)',
#  '3080國家發展研究所碩士班乙組(主修中國大陸與東亞研究)',
#  '3090新聞研究所碩士班',
#  '3100公共事務研究所碩士班',
#  '4010臨床牙醫學研究所碩士班甲組(主修口腔病理學)',
#  '4020臨床牙醫學研究所碩士班乙組(主修牙體復形及美容牙科學)',
#  '4030臨床牙醫學研究所碩士班丙組(主修牙髓病學)',
#  '4040臨床牙醫學研究所碩士班丁組(主修牙周病學)',
#  '4050臨床牙醫學研究所碩士班戊組(主修補綴學)',
#  '4060臨床牙醫學研究所碩士班己組(主修兒童牙科學)',
#  '4070臨床牙醫學研究所碩士班庚組(主修齒顎矯正學)',
#  '4080臨床牙醫學研究所碩士班辛組(主修口腔顎面外科學)',
#  '4090藥學系碩士班甲組(主修新藥探索)',
#  '4100藥學系碩士班乙組(主修製藥科技)',
#  '4110藥學系碩士班丙組(主修醫藥生技)',
#  '4120醫學檢驗暨生物技術學系碩士班',
#  '4130護理學系碩士班甲組(專科護理師組)',
#  '4140護理學系碩士班乙組(臨床研究護理師組)',
#  '4150護理學系碩士班丙組(內外科護理組)',
#  '4160護理學系碩士班丁組(婦女健康暨母嬰護理組)',
#  '4170護理學系碩士班戊組(兒童暨家庭護理組)',
#  '4180護理學系碩士班己組(精神暨心理衛生護理組)',
#  '4190護理學系碩士班庚組(社區護理組)',
#  '4200物理治療學系碩士班',
#  '4210職能治療學系碩士班',
#  '4220生理學研究所碩士班',
#  '4230生物化學暨分子生物學研究所碩士班',
#  '4240藥理學研究所碩士班',
#  '4250病理學研究所碩士班',
#  '4260微生物學研究所碩士班',
#  '4261微生物學研究所碩士班微生物及免疫學組',
#  '4262微生物學研究所碩士班熱帶醫學暨寄生蟲學組',
#  '4270解剖學暨細胞生物學研究所碩士班',
#  '4280毒理學研究所碩士班',
#  '4290分子醫學研究所碩士班',
#  '4300免疫學研究所碩士班',
#  '4310口腔生物科學研究所碩士班',
#  '4320臨床藥學研究所碩士班',
#  '4330臨床藥學研究所碩士班',
#  '4340法醫學研究所碩士班',
#  '4350腦與心智科學研究所碩士班',
#  '4360基因體暨蛋白體醫學研究所碩士班',
#  '4370醫學教育暨生醫倫理研究所碩士班',
#  '4380醫療器材與醫學影像研究所碩士班',
#  '4390醫療器材與醫學影像研究所碩士班',
#  '4400國際三校農業生技與健康醫療碩士學位學程',
#  '5010土木工程學系碩士班大地工程組',
#  '5020土木工程學系碩士班測量及空間資訊組',
#  '5030土木工程學系碩士班測量及空間資訊組',
#  '5040土木工程學系碩士班結構工程組',
#  '5050土木工程學系碩士班水利工程組',
#  '5060土木工程學系碩士班水利工程組',
#  '5070土木工程學系碩士班交通工程甲組(主修交通運輸）',
#  '5080土木工程學系碩士班交通工程甲組(主修交通運輸）',
#  '5090土木工程學系碩士班交通工程乙組(主修道路及機場工程)',
#  '5100土木工程學系碩士班電腦輔助工程組',
#  '5110土木工程學系碩士班電腦輔助工程組',
#  '5120土木工程學系碩士班營建工程與管理',
#  '5130機械工程學系碩士班',
#  '5131機械工程學系碩士班固體力學組',
#  '5132機械工程學系碩士班設計組',
#  '5133機械工程學系碩士班製造組',
#  '5134機械工程學系碩士班流體力學組',
#  '5135機械工程學系碩士班熱學組',
#  '5136機械工程學系碩士班系統控制組',
#  '5140機械工程學系碩士班',
#  '5141機械工程學系碩士班熱學組',
#  '5142機械工程學系碩士班製造組',
#  '5150化學工程學系碩士班',
#  '5160工程科學及海洋工程學系碩士班甲組(主修流體力學、船舶工程、海洋工程)',
#  '5170工程科學及海洋工程學系碩士班乙組(主修固力結構)',
#  '5180工程科學及海洋工程學系碩士班丙組(主修光電、機電、電機電子)',
#  '5190工程科學及海洋工程學系碩士班丁組(主修資訊科技、計算科學)',
#  '5200材料科學與工程學系碩士班甲組(主修金屬、製程、陶瓷能源材料)',
#  '5210材料科學與工程學系碩士班乙組(主修高分子及軟質材料)',
#  '5220材料科學與工程學系碩士班丙組(主修電子材料)',
#  '5230材料科學與工程學系國際應用材料工程碩士班',
#  '5240環境工程學研究所碩士班',
#  '5241環境工程學研究所碩士班環境科學與工程組',
#  '5242環境工程學研究所碩士班環境規劃與管理組',
#  '5250應用力學研究所碩士班甲組(主修動力學或固體力學)',
#  '5260應用力學研究所碩士班乙組(主修流體力學)',
#  '5270建築與城鄉研究所碩士班空間規劃設計專業組',
#  '5280建築與城鄉研究所碩士班其他專業組',
#  '5290建築與城鄉研究所碩士班原住民組',
#  '5300工業工程學研究所碩士班甲組',
#  '5310工業工程學研究所碩士班乙組',
#  '5320醫學工程學系碩士班甲組(主修材料)',
#  '5330醫學工程學系碩士班乙組(主修力學)',
#  '5340醫學工程學系碩士班丙組(主修電機、電子、資訊)',
#  '5350醫學工程學系碩士班丁組(主修生物、醫、農)',
#  '5360高分子科學與工程學研究所碩士班',
#  '5370綠色永續材料與精密元件博士學位學程',
#  '6010農藝學系碩士班作物科學甲組(主修生理、生物技術、生產管理)',
#  '6020農藝學系碩士班作物科學甲組(主修生理、生物技術、生產管理)',
#  '6030農藝學系碩士班作物科學乙組(主修遺傳、分子育種)',
#  '6040農藝學系碩士班生物統計學甲組(主修試驗統計、生物資訊)',
#  '6050農藝學系碩士班生物統計學乙組(主修理論統計、生物資訊)',
#  '6060生物環境系統工程學系碩士班',
#  '6070農業化學系碩士班甲組(主修土壤環境與植物營養學)',
#  '6080農業化學系碩士班乙組(主修微生物學)',
#  '6090農業化學系碩士班丙組(主修食品化學與加工)',
#  '6100森林環境暨資源學系碩士班',
#  '6110森林環境暨資源學系碩士班',
#  '6120動物科學技術學系碩士班',
#  '6130農業經濟學系碩士班',
#  '6140園藝暨景觀學系碩士班園藝作物組',
#  '6150園藝暨景觀學系碩士班園產品處理及利用組',
#  '6160園藝暨景觀學系碩士班景觀暨休憩組',
#  '6170獸醫學系碩士班甲組(主修獸醫公共衛生及預防醫學)',
#  '6180獸醫學系碩士班乙組(主修基礎動物醫學)',
#  '6190生物產業傳播暨發展學系碩士班',
#  '6200生物機電工程學系碩士班',
#  '6210昆蟲學系碩士班',
#  '6220植物病理與微生物學系碩士班',
#  '6230食品科技研究所碩士班甲組(主修食品化學)',
#  '6240食品科技研究所碩士班乙組(主修食品微生物)',
#  '6250食品科技研究所碩士班丙組(主修食品加工)',
#  '6260食品科技研究所碩士班丁組(主修食品工程)',
#  '6270食品科技研究所碩士班戊組(主修保健營養)',
#  '6280生物科技研究所碩士班',
#  '6290臨床動物醫學研究所碩士班甲組(伴侶動物組)',
#  '6300臨床動物醫學研究所碩士班乙組(大動物及野生動物組)',
#  '6310植物醫學碩士學位學程',
#  '6320植物醫學碩士學位學程',
#  '6330分子暨比較病理生物學研究所碩士班甲組',
#  '6340分子暨比較病理生物學研究所碩士班乙組',
#  '7010商學研究所碩士班',
#  '7020會計學系碩士班甲組(主修會計)',
#  '7030會計學系碩士班乙組(主修商業智慧與資料分析)',
#  '7040財務金融學系碩士班甲組(主修財務金融)',
#  '7050財務金融學系碩士班乙組(主修財務工程)',
#  '7060財務金融學系碩士班丙組(主修風險管理與保險)',
#  '7070國際企業學系碩士班',
#  '7080資訊管理學系碩士班',
#  '8010健康政策與管理研究所碩士班',
#  '8020健康行為與社區科學研究所碩士班',
#  '8030環境與職業健康科學研究所碩士班',
#  '8040環境與職業健康科學研究所及流行病學與預防醫學研究所臺大-京大雙聯學位組',
#  '8041環境與職業健康科學研究所及流行病學與預防醫學研究所環境與職業健康科學研究所',
#  '8042環境與職業健康科學研究所及流行病學與預防醫學研究所流行病學與預防醫學研究所',
#  '8050流行病學與預防醫學研究所碩士班甲組(主修流行病學)',
#  '8060流行病學與預防醫學研究所碩士班乙組(主修生物醫學統計學)',
#  '8070流行病學與預防醫學研究所碩士班丙組(主修預防醫學)',
#  '8080公共衛生碩士學位學程',
#  '8090食品安全與健康研究所碩士班',
#  '9010電機工程學系碩士班甲組(主修自動控制)',
#  '9020電機工程學系碩士班乙組(主修電力系統與電力電子)',
#  '9030電機工程學系碩士班丙組(主修計算機科學)',
#  '9040電機工程學系資訊安全碩士班',
#  '9050資訊工程學系碩士班',
#  '9060資訊工程學系人工智慧碩士班',
#  '9070光電工程學研究所碩士班',
#  '9080電信工程學研究所碩士班甲組(主修電波)',
#  '9090電信工程學研究所碩士班乙組(主修通訊與信號處理)',
#  '9100電信工程學研究所碩士班丙組(主修資料科學與智慧網路)',
#  '9110電子工程學研究所碩士班甲組(主修數位積體電路與系統)',
#  '9120電子工程學研究所碩士班乙組(主修類比積體電路與系統)',
#  '9130電子工程學研究所碩士班丙組(主修奈米電子含光電半導體)',
#  '9140電子工程學研究所碩士班丁組(主修電子設計自動化)',
#  '9150資訊網路與多媒體研究所碩士班',
#  '9160生醫電子與資訊學研究所碩士班甲組(主修生醫電子一)',
#  '9170生醫電子與資訊學研究所碩士班乙組(主修生醫電子二)',
#  '9180生醫電子與資訊學研究所碩士班丙組(主修生醫資訊)',
#  '9190資料科學碩士學位學程',
#  'A010法律學系碩士班甲組(主修基礎法學)',
#  'A020法律學系碩士班乙組(主修公法學)',
#  'A030法律學系碩士班丙組(主修民事法學)',
#  'A040法律學系碩士班丁組(主修刑事法學)',
#  'A050法律學系碩士班戊組(主修財稅法學)',
#  'A060法律學系碩士班己組(主修經濟法學)',
#  'A070法律學系碩士班庚組(主修國際法學)',
#  'A080法律學系碩士班辛組(主修商事法學)',
#  'B010生命科學系碩士班',
#  'B020植物科學研究所碩士班',
#  'B030分子與細胞生物學研究所碩士班',
#  'B040生態學與演化生物學研究所碩士班',
#  'B050漁業科學研究所碩士班',
#  'B060生化科學研究所碩士班',
#  'B070生化科技學系碩士班',
#  'B080基因體與系統生物學碩士學位學程',
#  'H010統計碩士學位學程',
#  'H020運動設施與健康管理碩士學位學程運動管理組',
#  'H030運動設施與健康管理碩士學位學程運動管理組',
#  'H040運動設施與健康管理碩士學位學程健康管理組',
#  'H050運動設施與健康管理碩士學位學程健康管理組']
# </textarea>

# %%
from selenium.webdriver.support.ui import Select
from selenium import webdriver
from bs4 import BeautifulSoup
import pandas as pd

driver = webdriver.PhantomJS(executable_path='./phantomjs-2.1.1-linux-x86_64/bin/phantomjs')
driver.get('http://gra108.aca.ntu.edu.tw/regbchk/stu_query.asp')

s1 = Select(driver.find_element_by_name('DEP'))

avaliable_department = []

for select in s1.options:
    avaliable_department.append(select.text)
    
avaliable_department
# Out:
# ['請選擇',
#  '101 中國文學系碩士班',
#  '102 外國語文學系碩士班',
#  '103 歷史學系碩士班',
#  '104 哲學系碩士班甲組(主修東方哲學)',
#  '105 哲學系碩士班乙組(主修西方哲學)',
#  '106 人類學系碩士班',
#  '107 圖書資訊學系碩士班甲組',
#  '108 圖書資訊學系碩士班乙組',
#  '109 日本語文學系碩士班',
#  '110 戲劇學系碩士班',
#  '111 藝術史研究所碩士班',
#  '112 語言學研究所碩士班',
#  '113 音樂學研究所碩士班',
#  '114 臺灣文學研究所碩士班',
#  '115 華語教學碩士學位學程',
#  '116 翻譯碩士學位學程甲組(主修筆譯)',
#  '117 翻譯碩士學位學程乙組(主修口譯)',
#  '201 數學系碩士班',
#  '202 物理學系、天文物理研究所及應用物理學研究所碩士班聯合招生',
#  '202A物理學系碩士班',
#  '202B天文物理研究所碩士班',
#  '202C應用物理學研究所碩士班',
#  '203 化學系碩士班化學組',
#  '204 化學系碩士班化學生物學組',
#  '205 地質科學系碩士班地質組',
#  '206 地質科學系碩士班應用地質組',
#  '207 心理學系碩士班一般心理學甲組',
#  '208 心理學系碩士班一般心理學乙組',
#  '209 心理學系碩士班一般心理學丙組',
#  '210 心理學系碩士班臨床心理學組',
#  '211 地理環境資源學系碩士班甲組(主修自然地理)',
#  '212 地理環境資源學系碩士班乙組(主修人文地理)',
#  '213 地理環境資源學系碩士班丙組(主修地理資訊科學)',
#  '214 大氣科學系碩士班甲組',
#  '215 大氣科學系碩士班乙組',
#  '216 海洋研究所碩士班海洋物理、海洋化學、海洋地質及地球物理組',
#  '216A海洋研究所碩士班',
#  '216B海洋研究所碩士班',
#  '216C海洋研究所碩士班',
#  '217 海洋研究所碩士班海洋生物及漁業組',
#  '218 應用數學科學研究所碩士班應用數學組',
# ...

# %% [markdown]
# ## Step 2 Try to grab admission information of a specific department
# Grab the admission information of a specific department according to the last three codes of your student ID.
# For example, if your student ID is r08942161, your have to grap department in index number 161 that is '6240食品科技研究所碩士班乙組(主修食品微生物)'.
# Then, use pandas to organize data and print it out.
#
# Sameple Output:
#
# ||序號|准考證|姓名|正備取|報到狀態|遞補狀態|備註|
# |--------| -------- | -------- |  -------- | -------- | -------- | -------- | -------- |
# |0|1|6240012|雷O芸|正取1|志願1|||
# |1|2|6240011|黃O綺|正取2|志願1|||

# %%
dep_name = avaliable_department[161]

s1.select_by_index(161)  #更改這個可以對應到不同的研究所
driver.find_element_by_name('qry').click()

soup = BeautifulSoup(driver.page_source, "html.parser")

a_tags = soup.select('td')
table = soup.find('table', {'class': 'w15'})
columns = [ th.text.replace('\n', '') for th in table.find('tr').find_all('td')]
print(columns)
trs = table.find_all('tr')[1:]
rows = list()
for tr in trs:
    rows.append([td.text.replace('\n', '').replace('\xa0', '').replace('\t', '') for td in tr.find_all('td')])

df = pd.DataFrame(data=rows, columns=columns)
df
# Out:
# ['序號', '准考證', '姓名', '正備取', '報到狀態', '遞補狀態', '備註']
#    序號        准考證   姓名   正備取 報到狀態 遞補狀態 備註
# 0   1  627150003  楊○宏   正取1  志願1
# 1   2  627150005   何○   正取2  志願1
# 2   3  627150008  黃○育   正取3  志願1
# 3   4  627150001  范○維   正取4  志願1
# 4   5  627150010  蔡○燁   正取5  志願1
# 5   6  627150011  黃○郁  備取 1  志願1
# 6   7  627150004  顏○峰  備取 2  志願1
# 7   8  627150016  劉○嘉  備取 3  未報到
# 8   9  627150009  楊○儒  備取 4  志願1
# 9  10  627150014  阮○澔  備取 5  志願1

# %% [markdown]
# ## Step 3 Count the number of people who were originally on the waiting list but were finally admitted
#
# Sample Output:
# <textarea readonly rows="6" cols="60">
# 6240食品科技研究所碩士班乙組(主修食品微生物)
# 已放棄：0
# 未報到：0
# 已報到：2
# </textarea>

# %%
df.values[6][2]
# Out:
# '顏○峰'

# %%
count = 0
for i in df.values:
    if int(i[0]) < 58:
        if i[4] == '已放棄':
            count = count+1
count2 = 0
for i in df.values:
    if int(i[0]) < 58:
        if i[4] == '未報到':
            count2 = count2+1
count3 = 0
for i in df.values:
    if int(i[0]) < 58:
        if i[4] != '未報到' and i[4] != '已放棄':
         count3 = count3+1
        
print('{} \n已放棄：'.format(dep_name)+str(count)+"\n未報到："+str(count2)+"\n已報到："+str(count3))
# Out:
# 627 昆蟲學系碩士班
# 已放棄：0
# 未報到：1
# 已報到：9

# %% [markdown]
# ## Step 4 Send your result with email to TA
# **TA's email** :
# **Subject** : [Computer_Programming](your student ID)
# **Content** :
#
# |   系所   |   備取上人數   |
# | -------- | -------- |
# |6240食品科技研究所碩士班乙組(主修食品微生物)|0人|

# %%
# Step 4
import email, getpass
from email.header import decode_header, make_header
from email.message import EmailMessage
from smtplib import SMTP
NTU_SMTP = 'smtps.ntu.edu.tw'

with SMTP(NTU_SMTP) as smtp:
    # a connection is required before login and sendemail.
    # https://stackoverflow.com/questions/37224073/smtp-auth-extension-not-supported-by-server
    smtp.connect(NTU_SMTP, 587)
    smtp.ehlo()
    resp = smtp.starttls()
    print(resp)
    if resp[0] == 220:
        ntu_id = input('NTU Student ID: ')
        ntu_id = ntu_id.rstrip('@ntu.edu.tw')
        smtp.login(ntu_id, getpass.getpass('Password: '))
        to_email = input('Send To: ')
        subject = input('Subject: ')
        content = input('Content: ')
        msg = EmailMessage()
        custom_from = input('自訂寄信者名稱? (y/N) ')[:1].lower() == 'y'
        if custom_from:
            msg['From'] = input('Name <user@mail>\n')
        else:
            msg['From'] = ntu_id + '@ntu.edu.tw'
        msg['To'] = to_email
        msg['Subject'] = subject
        msg.set_content(content)
        smtp.send_message(msg)
# Out:
# (220, b'2.0.0 Ready to start TLS')
# NTU Student ID: r08921a25
# Password: ········
# Send To: r08942071@ntu.edu.tw
# Subject: hihi
# Content: hihihi
# 自訂寄信者名稱? (y/N) N

# %% [markdown]
# <img src=https://i.imgur.com/2XkQ8KU.jpg width=300px>
