# %% [markdown]
# # Week14 network programming (1)

# %% [markdown]
# In the classroom, we will learned how to use python to do basic web crawlers and how to use python to send email.
#
# * python crawler
# * send email

# %% [markdown]
# # Tasks
# In this lab, we will practice grabbing the information in the online registration and query system for enrollment of the master’s class(碩士班招生正備取生網路報到查詢系統) and list the number of waiting list of each institute .
# http://gra108.aca.ntu.edu.tw/regbchk/stu_query.asp
#
# ![image.png](attachment:image.png)
#
# Please follow the steps below:

# %% [markdown]
# #### Note
# 執行 driver = webdriver.Chrome() 先下載 chromedriver.exe 到當前資料夾
#
# 下載網址 : https://chromedriver.chromium.org/downloads
#
# **要確認下載的版本和目前本地端 chorme 一致**
#
# > (確認 chorme 目前版本 : 開啟 chorme / 設定 / 關於 chorme)
#
# 當前資料夾應長這樣 :
# ![image.png](attachment:image.png)

# %% [markdown]
# ## Step 1 List all avaliable department
#
# Sample Output:
# <textarea readonly rows="10" cols="80">
# ['請選擇',
#  '101 中國文學系碩士班',
#  '102 外國語文學系碩士班',
#  '103 歷史學系碩士班',
#  '104 哲學系碩士班甲組(主修東方哲學)',
#  '105 哲學系碩士班乙組(主修西方哲學)',
#  '106 人類學系碩士班',
#  '107 圖書資訊學系碩士班甲組',
#  '108 圖書資訊學系碩士班乙組',
#  '109 日本語文學系碩士班',
#  '110 戲劇學系碩士班',
#  '111 藝術史研究所碩士班',
#  '112 語言學研究所碩士班',
#  '113 音樂學研究所碩士班',
#  '114 臺灣文學研究所碩士班',
#  '115 華語教學碩士學位學程',
#  '116 翻譯碩士學位學程甲組(主修筆譯)',
#  '117 翻譯碩士學位學程乙組(主修口譯)',
#  '201 數學系碩士班',
#  '202 物理學系、天文物理研究所及應用物理學研究所碩士班聯合招生',
#  '202A物理學系碩士班',
#  '202B天文物理研究所碩士班',
#  '202C應用物理學研究所碩士班',
#  '203 化學系碩士班化學組',
#  '204 化學系碩士班化學生物學組',
#  '205 地質科學系及海洋研究所碩士班聯合招生地質系地質、應用地質組及海洋所海洋地質及地球物理組',
#  '205A地質科學系碩士班地質組',
#  '205B地質科學系碩士班應用地質組',
#  '205C海洋研究所碩士班海洋地質及地球物理組',
#  '206 心理學系碩士班一般心理學甲組',
#  '207 心理學系碩士班一般心理學乙組',
#  '208 心理學系碩士班一般心理學丙組',
#  '209 心理學系碩士班臨床心理學組',
#  '210 地理環境資源學系碩士班甲組(主修自然地理)',
#  '211 地理環境資源學系碩士班乙組(主修人文地理)',
#  '212 地理環境資源學系碩士班丙組(主修地理資訊科學)',
#  '213 大氣科學系碩士班甲組',
#  '214 大氣科學系碩士班乙組',
#  '215 海洋研究所碩士班海洋物理、海洋化學組',
#  '215A海洋研究所碩士班海洋物理組',
#  '215B海洋研究所碩士班海洋化學組',
#  '216 海洋研究所碩士班海洋生物及漁業組',
#  '217 應用數學科學研究所碩士班',
#  '218 氣候變遷與永續發展國際碩士學位學程',
#  '219 統計與數據科學研究所碩士班',
#  '301 政治學系碩士班甲組(主修政治理論與制度)',
#  '302 政治學系碩士班乙組(主修國際關係)',
#  '303 經濟學系碩士班',
#  '304 社會學系碩士班',
#  '305 社會工作學系碩士班',
#  '306 國家發展研究所碩士班甲組(主修全球化與科技治理)',
#  '307 國家發展研究所碩士班乙組(主修中國大陸與東亞研究)',
#  '308 新聞研究所碩士班',
#  '309 公共事務研究所碩士班',
#  '401 臨床牙醫學研究所碩士班甲組(主修口腔病理學)',
#  '402 臨床牙醫學研究所碩士班乙組(主修牙體復形及美容牙科學)',
#  '403 臨床牙醫學研究所碩士班丙組(主修牙髓病學)',
#  '404 臨床牙醫學研究所碩士班丁組(主修牙周病學)',
#  '405 臨床牙醫學研究所碩士班戊組(主修補綴學)',
#  '406 臨床牙醫學研究所碩士班己組(主修兒童牙科學)',
#  '407 臨床牙醫學研究所碩士班庚組(主修齒顎矯正學)',
#  '408 臨床牙醫學研究所碩士班辛組(主修口腔顎面外科學)',
#  '409 藥學系碩士班',
#  '410 醫學檢驗暨生物技術學系碩士班',
#  '411 護理學系碩士班甲組(專科護理師組)',
#  '412 護理學系碩士班乙組(臨床研究護理師組)',
#  '413 護理學系碩士班丙組(內外科護理組)',
#  '414 護理學系碩士班丁組(婦女健康暨母嬰護理組)',
#  '415 護理學系碩士班戊組(兒童暨家庭護理組)',
#  '416 護理學系碩士班己組(精神暨心理衛生護理組)',
#  '417 護理學系碩士班庚組(社區護理組)',
#  '418 物理治療學系碩士班',
#  '419 職能治療學系碩士班',
#  '420 生理學研究所碩士班',
#  '421 生物化學暨分子生物學研究所碩士班',
#  '422 藥理學研究所碩士班',
#  '423 病理學研究所碩士班分子病理組',
#  '424 病理學研究所碩士班病理檢驗組',
#  '425 微生物學研究所碩士班微生物及免疫學組',
#  '426 微生物學研究所碩士班熱帶醫學暨寄生蟲學組',
#  '427 解剖學暨細胞生物學研究所碩士班',
#  '428 毒理學研究所碩士班',
#  '429 分子醫學研究所碩士班',
#  '430 免疫學研究所碩士班',
#  '431 口腔生物科學研究所碩士班',
#  '432 臨床藥學研究所碩士班',
#  '433 法醫學研究所碩士班甲組',
#  '434 法醫學研究所碩士班乙組',
#  '435 基因體暨蛋白體醫學研究所碩士班',
#  '436 腦與心智科學研究所碩士班',
#  '437 醫學教育暨生醫倫理研究所碩士班',
#  '438 醫療器材與醫學影像研究所',
#  '439 國際三校農業生技與健康醫療碩士學位學程',
#  '501 土木工程學系碩士班大地工程組',
#  '502 土木工程學系碩士班大地工程組',
#  '503 土木工程學系碩士班結構工程組',
#  '504 土木工程學系碩士班結構工程組',
#  '505 土木工程學系碩士班水利工程組',
#  '506 土木工程學系碩士班水利工程組',
#  '507 土木工程學系碩士班交通工程組',
#  '508 土木工程學系碩士班營建工程與管理組',
#  '509 機械工程學系碩士班固體力學組',
#  '510 機械工程學系碩士班設計組',
#  '511 機械工程學系碩士班製造組',
#  '512 機械工程學系碩士班流體力學組',
#  '513 機械工程學系碩士班熱學組',
#  '514 機械工程學系碩士班航空工程組',
#  '515 機械工程學系碩士班系統控制組',
#  '516 化學工程學系碩士班',
#  '517 工程科學及海洋工程學系碩士班甲組',
#  '518 工程科學及海洋工程學系碩士班乙組',
#  '519 工程科學及海洋工程學系碩士班丙組',
#  '520 工程科學及海洋工程學系碩士班丁組',
#  '521 材料科學與工程學系碩士班甲組(主修金屬、製程、陶瓷能源材料)',
#  '522 材料科學與工程學系碩士班乙組(主修高分子及軟質材料)',
#  '523 材料科學與工程學系碩士班丙組(主修電子材料）',
#  '524 材料科學與工程學系國際應用材料工程碩士班',
#  '525 環境工程學研究所碩士班環境科學與工程甲組',
#  '526 環境工程學研究所碩士班環境科學與工程乙組',
#  '527 環境工程學研究所碩士班環境科學與工程丙組',
#  '528 環境工程學研究所碩士班環境規劃與管理組',
#  '529 應用力學研究所碩士班甲組',
#  '530 應用力學研究所碩士班乙組',
#  '531 應用力學研究所碩士班丙組',
#  '532 建築與城鄉研究所碩士班甲組',
#  '533 建築與城鄉研究所碩士班乙組',
#  '534 建築與城鄉研究所碩士班丙組',
#  '535 建築與城鄉研究所碩士班丁組',
#  '536 工業工程學研究所碩士班產業與服務系統工程組',
#  '537 醫學工程學系碩士班甲組',
#  '538 醫學工程學系碩士班乙組',
#  '539 醫學工程學系碩士班丙組',
#  '540 醫學工程學系碩士班丁組',
#  '541 高分子科學與工程學研究所碩士班甲組',
#  '542 高分子科學與工程學研究所碩士班乙組',
#  '601 農藝學系碩士班作物科學甲組(主修生理、生物技術、生產管理)',
#  '602 農藝學系碩士班作物科學乙組(主修遺傳、分子育種)',
#  '603 農藝學系碩士班生物統計學組(主修生物統計、生物資訊)',
#  '604 生物環境系統工程學系碩士班甲組',
#  '605 生物環境系統工程學系碩士班乙組',
#  '606 農業化學系碩士班甲組(主修土壤環境與植物營養學)',
#  '607 農業化學系碩士班乙組(主修微生物學)',
#  '608 農業化學系碩士班丙組(主修食品化學與加工)',
#  '609 森林環境暨資源學系碩士班甲組(主修森林生物)',
#  '610 森林環境暨資源學系碩士班乙組(主修生物材料)',
#  '611 森林環境暨資源學系碩士班丙組(主修森林環境)',
#  '612 森林環境暨資源學系碩士班丁組(主修資源保育及管理)',
#  '613 動物科學技術學系碩士班',
#  '614 農業經濟學系碩士班',
#  '615 園藝暨景觀學系碩士班園藝作物組',
#  '616 園藝暨景觀學系碩士班園產品處理及利用組',
#  '617 園藝暨景觀學系碩士班景觀暨休憩組',
#  '618 獸醫學系碩士班甲組(主修獸醫公共衛生及預防醫學)',
#  '619 獸醫學系碩士班乙組(主修基礎動物醫學)',
#  '620 生物產業傳播暨發展學系碩士班',
#  '621 生物機電工程學系碩士班甲組(機電控制)',
#  '622 生物機電工程學系碩士班乙組(機械系統)',
#  '623 生物機電工程學系碩士班丙組(生物程序)',
#  '624 生物機電工程學系碩士班丁組(人工智慧)',
#  '625 昆蟲學系碩士班',
#  '626 植物病理與微生物學系碩士班甲組',
#  '627 植物病理與微生物學系碩士班乙組',
#  '628 食品科技研究所碩士班甲組(主修食品化學)',
#  '629 食品科技研究所碩士班乙組(主修食品微生物)',
#  '630 食品科技研究所碩士班丙組(主修食品加工)',
#  '631 食品科技研究所碩士班丁組(主修食品工程)',
#  '632 食品科技研究所碩士班戊組(主修保健營養)',
#  '633 生物科技研究所碩士班',
#  '634 臨床動物醫學研究所碩士班甲組(伴侶動物)',
#  '635 臨床動物醫學研究所碩士班乙組(大動物及野生動物)',
#  '636 植物醫學碩士學位學程',
#  '637 分子暨比較病理生物學研究所碩士班',
#  '701 商學研究所碩士班甲組',
#  '702 商學研究所碩士班乙組',
#  '703 會計學系碩士班會計組',
#  '704 財務金融學系碩士班甲組(主修財務金融)',
#  '705 財務金融學系碩士班乙組(主修財務工程)',
#  '706 財務金融學系碩士班丙組(主修風險管理與保險)',
#  '707 國際企業學系碩士班甲組',
#  '708 國際企業學系碩士班乙組',
#  '709 資訊管理學系碩士班',
#  '801 健康政策與管理研究所碩士班',
#  '802 健康行為與社區科學研究所碩士班',
#  '803 環境與職業健康科學研究所碩士班',
#  '804 流行病學與預防醫學研究所碩士班甲組(主修流行病學)',
#  '805 流行病學與預防醫學研究所碩士班乙組(主修預防醫學)',
#  '806 健康數據拓析統計研究所碩士班',
#  '807 公共衛生碩士學位學程',
#  '808 食品安全與健康研究所碩士班',
#  '901 電機工程學系碩士班甲組(主修自動控制)',
#  '902 電機工程學系碩士班乙組(主修電力系統與電力電子)',
#  '903 電機工程學系碩士班丙組(主修計算機科學)',
#  '904 電機工程學系資訊安全碩士班',
#  '905 資訊工程學系碩士班',
#  '906 資訊工程學系人工智慧碩士班',
#  '907 光電工程學研究所碩士班',
#  '908 電信工程學研究所碩士班甲組(主修電波)',
#  '909 電信工程學研究所碩士班乙組(主修通訊與信號處理)',
#  '910 電信工程學研究所碩士班丙組(主修資料科學與智慧網路)',
#  '911 電子工程學研究所甲組與積體電路設計與自動化碩士學位學程甲組聯合招生',
#  '911A電子工程學研究所碩士班甲組',
#  '911B積體電路設計與自動化碩士學位學程甲組',
#  '912 電子工程學研究所乙組與積體電路設計與自動化碩士學位學程乙組聯合招生',
#  '912A電子工程學研究所碩士班乙組',
#  '912B積體電路設計與自動化碩士學位學程乙組',
#  '913 電子工程學研究所碩士班丙組(主修奈米電子含光電半導體)',
#  '914 電子工程學研究所丁組與積體電路設計與自動化碩士學位學程丙組聯合招生',
#  '914A電子工程學研究所碩士班丁組',
#  '914B積體電路設計與自動化碩士學位學程丙組',
#  '915 資訊網路與多媒體研究所碩士班',
#  '916 生醫電子與資訊學研究所碩士班甲組(主修生醫電子一)',
#  '917 生醫電子與資訊學研究所碩士班乙組(主修生醫電子二)',
#  '918 生醫電子與資訊學研究所碩士班丙組(主修生醫資訊)',
#  '919 資料科學碩士學位學程',
#  'A01 法律學系碩士班甲組(主修基礎法學)',
#  'A02 法律學系碩士班乙組(主修公法學)',
#  'A03 法律學系碩士班丙組(主修民事法學)',
#  'A04 法律學系碩士班丁組(主修刑事法學)',
#  'A05 法律學系碩士班戊組(主修財稅法學)',
#  'A06 法律學系碩士班己組(主修經濟法學)',
#  'A07 法律學系碩士班庚組(主修國際法學)',
#  'A08 法律學系碩士班辛組(主修商事法學)',
#  'A09 科際整合法律學研究所碩士班',
#  'B01 生命科學系碩士班',
#  'B02 植物科學研究所碩士班',
#  'B03 分子與細胞生物學研究所碩士班',
#  'B04 生態學與演化生物學研究所碩士班',
#  'B05 漁業科學研究所碩士班',
#  'B06 生化科學研究所碩士班',
#  'B07 生化科技學系碩士班',
#  'H01 統計碩士學位學程',
#  'H02 運動設施與健康管理碩士學位學程運動管理組',
#  'H03 運動設施與健康管理碩士學位學程健康管理組',
#  'H04 智慧醫療與健康資訊碩士學位學程',
#  'K01 奈米工程與科學碩士學位學程',
#  'K02 元件材料與異質整合碩士學位學程']
# </textarea>

# %%
from selenium.webdriver.common.by import By
from selenium.webdriver.support.ui import Select
from selenium import webdriver
from bs4 import BeautifulSoup
import pandas as pd

driver = webdriver.Chrome()
driver.get('http://gra108.aca.ntu.edu.tw/regbchk/stu_query.asp')

s1 = Select(driver.find_element(By.NAME, 'DEP'))

avaliable_department = []

for select in s1.options:
    avaliable_department.append(select.text)
    
avaliable_department
# Out:
# ['請選擇',
#  '101 中國文學系碩士班',
#  '102 外國語文學系碩士班',
#  '103 歷史學系碩士班',
#  '104 哲學系碩士班甲組(主修東方哲學)',
#  '105 哲學系碩士班乙組(主修西方哲學)',
#  '106 人類學系碩士班',
#  '107 圖書資訊學系碩士班甲組',
#  '108 圖書資訊學系碩士班乙組',
#  '109 日本語文學系碩士班',
#  '110 戲劇學系碩士班',
#  '111 藝術史研究所碩士班',
#  '112 語言學研究所碩士班',
#  '113 音樂學研究所碩士班',
#  '114 臺灣文學研究所碩士班',
#  '115 華語教學碩士學位學程',
#  '116 翻譯碩士學位學程甲組(主修筆譯)',
#  '117 翻譯碩士學位學程乙組(主修口譯)',
#  '201 數學系碩士班',
#  '202 物理學系、天文物理研究所及應用物理學研究所碩士班聯合招生',
#  '202A物理學系碩士班',
#  '202B天文物理研究所碩士班',
#  '202C應用物理學研究所碩士班',
#  '203 化學系碩士班化學組',
#  '204 化學系碩士班化學生物學組',
#  '205 地質科學系及海洋研究所碩士班聯合招生地質系地質、應用地質組及海洋所海洋地質及地球物理組',
#  '205A地質科學系碩士班地質組',
#  '205B地質科學系碩士班應用地質組',
#  '205C海洋研究所碩士班海洋地質及地球物理組',
#  '206 心理學系碩士班一般心理學甲組',
#  '207 心理學系碩士班一般心理學乙組',
#  '208 心理學系碩士班一般心理學丙組',
#  '209 心理學系碩士班臨床心理學組',
#  '210 地理環境資源學系碩士班甲組(主修自然地理)',
#  '211 地理環境資源學系碩士班乙組(主修人文地理)',
#  '212 地理環境資源學系碩士班丙組(主修地理資訊科學)',
#  '213 大氣科學系碩士班甲組',
#  '214 大氣科學系碩士班乙組',
#  '215 海洋研究所碩士班海洋物理、海洋化學組',
#  '215A海洋研究所碩士班海洋物理組',
#  '215B海洋研究所碩士班海洋化學組',
# ...

# %% [markdown]
# ## Step 2 Try to grab admission information of a specific department
# Grab the admission information of a specific department according to the last three codes of your student ID.
# For example, if your student ID is r00000234, your have to grap department in index number 234 that is 'K01 奈米工程與科學碩士學位學程'.
# Then, use pandas to organize data and print it out.
#
# (hint : dataframe)
#
# ref: https://pandas.pydata.org/pandas-docs/stable/reference/api/pandas.DataFrame.html
#
# Sameple Output:
#
# ||序號|准考證|姓名|正備取|報到狀態|遞補狀態|備註|
# |--------| -------- | -------- |  -------- | -------- | -------- | -------- | -------- |
# |0|1|627150004|廖○立|正取1|已放棄||錄取放棄|
# |1|2|627150007|洪○誠|正取2|志願1|||

# %%
dep_name = avaliable_department[234]

s1.select_by_index(234)  #更改這個可以對應到不同的研究所
driver.find_element(By.NAME,'qry').click()

soup = BeautifulSoup(driver.page_source, "html.parser")


table = soup.find('table', {'class': 'w15'})
columns = [ th.text.replace('\n', '') for th in table.find('tr').find_all('td')]
print(columns)
trs = table.find_all('tr')[1:]
rows = list()
for tr in trs:
    rows.append([td.text.replace('\n', '').replace('\xa0', '').replace('\t', '') for td in tr.find_all('td')])

df = pd.DataFrame(data=rows, columns=columns)
df
# Out:
# ['序號', '准考證', '姓名', '正備取', '報到狀態', '遞補狀態', '備註']
#     序號        准考證   姓名    正備取  報到狀態           遞補狀態    備註
# 0    1  K01150019  莊○綺    正取1   已放棄
# 1    2  K01150012  羅○芸    正取2  全部放棄
# 2    3  K01150027  謝○晉    正取3   已放棄
# 3    4  K01150028  陳○合    正取4   已放棄
# 4    5  K01150025  曾○耘    正取5   志願1
# 5    6  K01150003  洪○哲    正取6   已放棄
# 6    7  K01150005  陳○欣    正取7   志願1
# 7    8  K01150004  翁○婷    正取8   志願1
# 8    9  K01150006  廖○芳   備取 1   已放棄                 錄取放棄
# 9   10  K01150026  劉○芸   備取 2   已放棄
# 10  11  K01150021  郭○儒   備取 3   志願1  遞補志願1(K01 )
# 11  12  K01150008  王○慶   備取 4   志願1  遞補志願1(K01 )
# 12  13  K01150007  葉○廷   備取 5   志願1  遞補志願1(K01 )
# 13  14  K01150002  蔡○霖   備取 6   已放棄
# 14  15  K01150001  吳○儒   備取 7   志願1  遞補志願1(K01 )
# 15  16  K01150015  李○安   備取 8   志願1  遞補志願1(K01 )
# 16  17  K01150014  陳○均   備取 9   已放棄
# 17  18  K01150013  汪○毅  備取 10   未報到
# 18  19  K01150009  許○淳  備取 11   志願1  遞補志願1(K01 )
# 19  20  K01150016  楊○緯  備取 12   已放棄
# ...

# %% [markdown]
# ## Step 3 Count the number of people who were originally on the waiting list but were finally admitted
#
# 利用 Step 2 完成的奈米工程所 dataframe 去計算
#
# Sample Output:
# <textarea readonly rows="6" cols="60">
# K01 奈米工程與科學碩士學位學程
# 已放棄：11
# 未報到：1
# 已報到：9
# </textarea>

# %%
print(len(df))
# Out:
# 21

# %%
count = 0
for i in df.values:
    if int(i[0]) < len(df) + 1:
        if i[4] == '已放棄' or i[4] == '全部放棄':
            count = count+1
count2 = 0
for i in df.values:
    if int(i[0]) < len(df) + 1:
        if i[4] == '未報到':
            count2 = count2+1
count3 = 0
for i in df.values:
    if int(i[0]) < len(df) + 1:
        if i[4] != '未報到' and i[4] != '已放棄' and i[4] != '全部放棄':
         count3 = count3+1
     
print('{} \n已放棄：'.format(dep_name)+str(count)+"\n未報到："+str(count2)+"\n已報到："+str(count3))
# Out:
# K01 奈米工程與科學碩士學位學程
# 已放棄：11
# 未報到：1
# 已報到：9

# %% [markdown]
# ## Step 4 Send your result with email to TA
# **Your student id's email** : your_student_id@ntu.edu.tw
#
# **Subject** : [ Lab14_Computer_Programming ] : your student ID
#
# **Content** :
# K01 奈米工程與科學碩士學位學程
# 已放棄：11
# 未報到：1
# 已報到：9

# %%
# Step 4
import email, getpass
from email.header import decode_header, make_header
from email.message import EmailMessage
from smtplib import SMTP
NTU_SMTP = 'smtps.ntu.edu.tw'

with SMTP(NTU_SMTP) as smtp:
    # a connection is required before login and sendemail.
    # https://stackoverflow.com/questions/37224073/smtp-auth-extension-not-supported-by-server
    smtp.connect(NTU_SMTP, 587)
    smtp.ehlo()
    resp = smtp.starttls()
    print(resp)
    if resp[0] == 220:
        ntu_id = input('NTU Student ID: ')
        print('NTU ID: {}'.format(ntu_id))
        ntu_id = ntu_id.rstrip('@ntu.edu.tw')
        smtp.login(ntu_id, getpass.getpass('Password: '))
        to_email = input('Send To: ')
        print('Send To: {}'.format(to_email))
        subject = input('Subject: ')
        print('Subject: {}'.format(subject))
        content = input('Content: ')
        print('Content: {}'.format(content))
        msg = EmailMessage()
        custom_from = input('自訂寄信者名稱? (y/N) ')[:1].lower() == 'y'
        if custom_from:
            msg['From'] = input('Name <user@mail>\n')
        else:
            msg['From'] = ntu_id + '@ntu.edu.tw'
        msg['To'] = to_email
        msg['Subject'] = subject
        msg.set_content(content)
        smtp.send_message(msg)
# Out:
# (220, b'2.0.0 Ready to start TLS')
# NTU ID: r12921a27
# Send To: fangyun1024@gmail.com
# Subject: [ Lab14_Computer_Programming ] : r12921a27
# Content: Hiiii

# %%
# 關閉瀏覽器
driver.quit()

# %% [markdown]
# <img src=https://i.imgur.com/2XkQ8KU.jpg width=300px>
